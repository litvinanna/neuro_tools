# %% [markdown]
# # All pics

# %%
from data_loading import *
import glob

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rc
rc('font',**{'family':'serif', "serif":"stix",  'size': 26})
rc('text', usetex=True)

def list_files(string):
    a = sorted(glob.glob(string), key = lambda x : x.split("/")[-1])
#     [print(x) for x in a]
    return a
# "../results/dnn/*/*all_runs**"

def boxplot(*args):
    test_list = []
    for arg in args:
        test_list += [test_accs(x) for x in list_files(arg)]
    [print(len(x), end = " ") for x in test_list]
    plt.boxplot(test_list,
            medianprops=dict(color="black", linewidth = 2),
            boxprops=dict(linewidth = 2),
            capprops=dict(linewidth = 2),
            whiskerprops=dict(linewidth = 2))
    return test_list

def make_significance(x1, x2, y, value):
    plt.plot([x1, x2], [y, y], marker="|", linewidth = 0.5, color = "black")
    plt.text((x1+x2)/2, y, value, horizontalalignment = "center", verticalalignment = "center")
    
def right_tick(test_list, *args):
    ax = plt.gca()
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    ax2.tick_params(axis='y', labelleft=False, labelright=True)
    values = [np.median(test_list[n]) for n  in args]
    labels = ["{:.1f}\%".format(round(i*100, 1)) for i in values]
    ax2.set_yticks(values)
    ax2.set_yticklabels(labels)
    [plt.hlines(np.median(test_list[n]), xmin=n+1, xmax=10, linestyles='dashed', linewidth = 1) for n in args]

# %% [markdown]
# # DNN

# %%
test_list = boxplot("../results/dnn/*/*1_all_runs_p1*100000*[_,0]0.*")
plt.ylim(0.29, 0.35)
ticks = (3, 6, 12, 24, 50)
plt.xticks(range(1, len(ticks) + 1), ticks)
plt.ylabel("accuracy")
plt.xlabel("predictor size")
plt.title("DNN model 1")
make_significance(2, 4, 0.344, "**")
right_tick(test_list, 4)
plt.savefig("../results/pics/dnn_model_1_all_runs_p1_ecoli_100000_10000_all_0.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/dnn/2019-04-29-17-17/dnn_model_1_all_runs_p1_ecoli_100000_10000_03_00.pyob
# file ../results/dnn/2019-04-27-13-50/dnn_model_1_all_runs_p1_ecoli_100000_10000_06_0.pyob
# file ../results/dnn/2019-04-27-14-51/dnn_model_1_all_runs_p1_ecoli_100000_10000_12_0.pyob
# file ../results/dnn/2019-04-27-15-59/dnn_model_1_all_runs_p1_ecoli_100000_10000_24_0.pyob
# file ../results/dnn/2019-04-29-18-08/dnn_model_1_all_runs_p1_ecoli_100000_10000_50_00.pyob
# 21 30 30 30 30

# %%
test_list = boxplot("../results/dnn/*/*2_all_runs_p1*100000*cds*")
plt.ylim(0.29, 0.35)
plt.xticks(range(1,4), (6, 12, 24))
plt.ylabel("accuracy")
plt.xlabel("predictor size")
plt.title("DNN model 2")
make_significance(1, 3, 0.344, "ns")
right_tick(test_list, 2)
plt.savefig("../results/pics/dnn_model_2_all_runs_p1_ecoli_100000_10000_all_0.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/dnn/2019-05-23-15-43/dnn_model_2_all_runs_p1_ecoli_100000_10000_06_00_cds_False.pyob
# file ../results/dnn/2019-05-23-17-12/dnn_model_2_all_runs_p1_ecoli_100000_10000_12_00_cds_False.pyob
# file ../results/dnn/2019-05-23-18-42/dnn_model_2_all_runs_p1_ecoli_100000_10000_24_00_cds_False.pyob
# 30 30 30

# %%
test_list = boxplot("../results/dnn/*/*2_all_runs_p2*100000*")
plt.ylim(0.29, 0.35)
plt.xticks(range(1,4), (6, 12, 24))
plt.ylabel("accuracy")
plt.xlabel("predictor size")
plt.title("DNN model 2")
make_significance(1, 3, 0.344, "ns")
right_tick(test_list, 2)
# plt.savefig("../results/pics/dnn_model_2_all_runs_p1_ecoli_100000_10000_all_0.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/dnn/2019-04-25-02-40/dnn_model_2_all_runs_p2_ecoli_100000_10000_12_0.pyob
# file ../results/dnn/2019-04-25-04-38/dnn_model_2_all_runs_p2_ecoli_100000_10000_24_0.pyob
# file ../results/dnn/2019-04-25-00-41/dnn_model_2_all_runs_p2_ecoli_100000_10000_6_0.pyob
# 30 30 30

# %%
test_list = boxplot("../results/dnn/*/*1_all_runs_p1*12_*")
plt.hlines(0.27, 0, 8, linewidth = 1, linestyle = "dashed")
plt.ylim(0.23, 0.34)
plt.yticks([0.25, 0.27, 0.3, 0.33])
plt.xticks(range(1,8), (0, 1, 2, 3, 6, 12, 50))
plt.ylabel("accuracy")
plt.xlabel("shift value")
# plt.title("DNN model 1")
plt.savefig("../results/pics/dnn_model_1_all_runs_p1_ecoli_100000_10000_12_all.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/dnn/2019-04-27-14-51/dnn_model_1_all_runs_p1_ecoli_100000_10000_12_0.pyob
# file ../results/dnn/2019-04-26-00-37/dnn_model_1_all_runs_p1_ecoli_100000_10000_12_01.pyob
# file ../results/dnn/2019-04-26-01-42/dnn_model_1_all_runs_p1_ecoli_100000_10000_12_02.pyob
# file ../results/dnn/2019-04-26-02-43/dnn_model_1_all_runs_p1_ecoli_100000_10000_12_03.pyob
# file ../results/dnn/2019-04-26-03-47/dnn_model_1_all_runs_p1_ecoli_100000_10000_12_06.pyob
# file ../results/dnn/2019-04-26-04-49/dnn_model_1_all_runs_p1_ecoli_100000_10000_12_12.pyob
# file ../results/dnn/2019-04-26-05-52/dnn_model_1_all_runs_p1_ecoli_100000_10000_12_50.pyob
# 30 30 30 30 30 30 30

# %%
plt.figure(figsize=(8, 4))
test_list = boxplot("../results/dnn/*/dnn_model_1_all_runs_p1_ecoli_100000_10000_06_0.pyob",
                    "../results/dnn/*/dnn_model_2_all_runs_p1_ecoli_100000_10000_06_0*cds*.pyob",
                   "../results/dnn/*/dnn_model_1_all_runs_p1_ecoli_100000_10000_12_0.pyob",
                    "../results/dnn/*/dnn_model_2_all_runs_p1_ecoli_100000_10000_12_0*cds*.pyob",
                   "../results/dnn/*/dnn_model_1_all_runs_p1_ecoli_100000_10000_24_0.pyob",
                    "../results/dnn/*/dnn_model_2_all_runs_p1_ecoli_100000_10000_24_0*cds*.pyob",)    

plt.ylim(0.29, 0.35)
plt.xticks(range(1, 7), [' 1 \n 6', ' 2 \n 6','1 \n 12', ' 2 \n 12',' 1 \n 24', ' 2 \n 24',], fontsize = 22)

make_significance(1, 2, 0.345, "***")
make_significance(3, 4, 0.345, "*")
make_significance(5, 6, 0.345, "ns")


plt.ylabel("test accuracy")
plt.text(0.7, 0.284, "model, no. layers", horizontalalignment = "right")
plt.text(0.7, 0.277, "predictor", horizontalalignment = "right")

right_tick(test_list, 5)

plt.savefig("../results/pics/dnn_models_all_runs_p1_ecoli_100000_10000_12_0.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/dnn/2019-04-27-13-50/dnn_model_1_all_runs_p1_ecoli_100000_10000_06_0.pyob
# file ../results/dnn/2019-05-23-15-43/dnn_model_2_all_runs_p1_ecoli_100000_10000_06_00_cds_False.pyob
# file ../results/dnn/2019-04-27-14-51/dnn_model_1_all_runs_p1_ecoli_100000_10000_12_0.pyob
# file ../results/dnn/2019-05-23-17-12/dnn_model_2_all_runs_p1_ecoli_100000_10000_12_00_cds_False.pyob
# file ../results/dnn/2019-04-27-15-59/dnn_model_1_all_runs_p1_ecoli_100000_10000_24_0.pyob
# file ../results/dnn/2019-05-23-18-42/dnn_model_2_all_runs_p1_ecoli_100000_10000_24_00_cds_False.pyob
# 30 30 30 30 30 30

# %% [markdown]
# # CNN

# %%
test_list = boxplot("../results/cnn/*/*1_all_runs_p1*100000*6_*")

plt.ylim(0.23, 0.34)
plt.hlines(0.26, 0, 8, linewidth = 1, linestyle = "dashed")
plt.yticks([0.25, 0.26, 0.3, 0.33])
plt.xticks(range(1,8), (0, 1, 2, 3, 6, 12, 50))
plt.ylabel("accuracy")
plt.xlabel("shift value")
# plt.title("CNN model k3*3")
plt.savefig("../results/pics/cnn_model_1_all_runs_p1_ecoli_100000_10000_6_all.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/cnn/2019-04-27-17-33/cnn_model_1_all_runs_p1_ecoli_100000_10000_06_0.pyob
# file ../results/cnn/2019-04-29-07-41/cnn_model_1_all_runs_p1_ecoli_100000_10000_6_01.pyob
# file ../results/cnn/2019-04-29-09-55/cnn_model_1_all_runs_p1_ecoli_100000_10000_6_02.pyob
# file ../results/cnn/2019-04-29-00-29/cnn_model_1_all_runs_p1_ecoli_100000_10000_6_03.pyob
# file ../results/cnn/2019-04-29-02-25/cnn_model_1_all_runs_p1_ecoli_100000_10000_6_06.pyob
# file ../results/cnn/2019-04-29-04-14/cnn_model_1_all_runs_p1_ecoli_100000_10000_6_12.pyob
# file ../results/cnn/2019-04-29-05-49/cnn_model_1_all_runs_p1_ecoli_100000_10000_6_50.pyob
# 30 30 30 30 30 30 30

# %%
test_list = boxplot("../results/cnn/*/*1_all_runs_p1*100000*_0.*")

plt.ylim(0.29, 0.35)
plt.xticks(range(1,5), (6, 12, 24, 50))
plt.ylabel("accuracy")
# plt.xlabel("predictor size")
plt.title("CNN model k3*3")
make_significance(1, 3, 0.344, "**")

plt.text(0.7, 0.284, "predictor size", horizontalalignment = "right")
right_tick(test_list, 3)
plt.savefig("../results/pics/cnn_model_1_all_runs_p1_ecoli_100000_10000_all_0.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/cnn/2019-04-27-17-33/cnn_model_1_all_runs_p1_ecoli_100000_10000_06_0.pyob
# file ../results/cnn/2019-04-27-20-10/cnn_model_1_all_runs_p1_ecoli_100000_10000_12_0.pyob
# file ../results/cnn/2019-04-27-22-52/cnn_model_1_all_runs_p1_ecoli_100000_10000_24_0.pyob
# file ../results/cnn/2019-05-01-10-18/cnn_model_1_all_runs_p1_ecoli_100000_10000_50_0.pyob
# 30 30 30 30

# %%
test_list = boxplot("../results/cnn/*/*2_all_runs_p1*100000*_00.*")

plt.ylim(0.29, 0.35)
plt.xticks(range(1,5), (6, 12, 24, 50))
plt.ylabel("accuracy")
# plt.xlabel("predictor size")
plt.title("CNN model k6*3")
make_significance(2, 4, 0.345, "**")
plt.text(0.7, 0.284, "predictor size", horizontalalignment = "right")
right_tick(test_list, 3)
plt.savefig("../results/pics/cnn_model_2_all_runs_p1_ecoli_100000_10000_all_0.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/cnn/2019-05-01-17-07/cnn_model_2_all_runs_p1_ecoli_100000_10000_06_00.pyob
# file ../results/cnn/2019-05-01-18-30/cnn_model_2_all_runs_p1_ecoli_100000_10000_12_00.pyob
# file ../results/cnn/2019-05-01-20-40/cnn_model_2_all_runs_p1_ecoli_100000_10000_24_00.pyob
# file ../results/cnn/2019-05-01-23-06/cnn_model_2_all_runs_p1_ecoli_100000_10000_50_00.pyob
# 30 30 30 30

# %%
# files = sorted(glob.glob(), key = lambda x : x.split("/")[-1])
# files += sorted(glob.glob("../results/cnn/*/*3_all_runs_p*100000**"), key = lambda x : x.split("/")[-1])
# files += sorted(glob.glob("../results/cnn/*/*6_all_runs_p*100000**"), key = lambda x : x.split("/")[-1])
# files[0], files[1] = files[1], files[0]

plt.figure(figsize=(8,4))
test_list = boxplot("../results/cnn/*/*_2_all_runs_p1*100000*12_*.*",
                    "../results/cnn/*/*_[1,4,5]_all_runs_p1*100000*12_*.*")

plt.ylim(0.29, 0.35)
plt.xticks(range(1,5), [
         "k6*3 \n12", "k3*3\n 12", "k3*6 \n 12",  "k3*12 \n 12", 
#         "k3*3\n 3 \n 12",  "k3*3\n 3 \n 51" ," k3*12\n 3 \n 12 "
    ], 
#   rotation = 'vertical' 
          )
plt.ylabel("accuracy")
make_significance(1, 2, .34, "ns")
make_significance(2, 3, .345, "***")
make_significance(3, 4, .347, "ns")

plt.text(0.5, 0.285, "conv layer", horizontalalignment = "right")
# plt.text(0.5, 0.278, "stride", horizontalalignment = "right")
plt.text(0.5, 0.278, "predictor", horizontalalignment = "right")
right_tick(test_list, 3)

plt.savefig("../results/pics/cnn_models_all_runs_p1_ecoli_100000_10000_12_0.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/cnn/2019-05-01-18-30/cnn_model_2_all_runs_p1_ecoli_100000_10000_12_00.pyob
# file ../results/cnn/2019-04-27-20-10/cnn_model_1_all_runs_p1_ecoli_100000_10000_12_0.pyob
# file ../results/cnn/2019-05-16-23-06/cnn_model_4_all_runs_p1_ecoli_100000_10000_12_00_cds_False.pyob
# file ../results/cnn/2019-05-17-20-34/cnn_model_5_all_runs_p1_ecoli_100000_10000_12_00_cds_False.pyob
# 30 30 30 30

# %%
plt.figure(figsize=(8,4))
test_list = boxplot("../results/cnn/*/*3_all_runs_p*100000**",
                   "../results/cnn/*/*6_all_runs_p*100000**")
plt.ylim(0.29, 0.353)
plt.xticks(range(1,5), [
#          "k6*3 \n-\n 12", "k3*3\n-\n 12", "k3*6 \n-\n 12",  "k3*12 \n-\n 12", 
        "k3*3\n 3 \n 12",  "k3*3\n 3 \n 51" ," k3*12\n 3 \n 12 ", "k3*12\n 3\n 51"], 
#   rotation = 'vertical' 
          )
plt.ylabel("accuracy")

plt.text(0.5, 0.285, "conv layer", horizontalalignment = "right")
plt.text(0.5, 0.278, "stride", horizontalalignment = "right")
plt.text(0.5, 0.271, "predictor", horizontalalignment = "right")


right_tick(test_list, 2, 3)

plt.savefig("../results/pics/cnn_models_stride.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/cnn/2019-05-17-00-41/cnn_model_3_all_runs_p1_ecoli_100000_10000_12_00_cds_False.pyob
# file ../results/cnn/2019-05-17-11-15/cnn_model_3_all_runs_p2_ecoli_100000_10000_51_00_cds_False.pyob
# file ../results/cnn/2019-05-26-16-26/cnn_model_6_all_runs_p1_ecoli_100000_10000_12_00_cds_False.pyob
# file ../results/cnn/2019-05-28-00-26/cnn_model_6_all_runs_p1_ecoli_100000_10000_51_00.pyob
# 30 30 30 30

# %%
plt.figure(figsize=(10,4))
test_list = boxplot("../results/cnn/*/*[4,5]_all_runs_p1*100000*_51*.*", 
                   "../results/cnn/*/*[4,5]_all_runs_p1*100000*_99*.*")
plt.ylim(0.31, 0.36)
plt.xticks(range(1,7), [
    "k3*6 \n 51", "k3*6 \n 51 cds", "k3*12\n 51", "k3*12 \n 51 cds", "k3*12 \n 99", "k3*12 \n 99 cds", 
])

plt.ylabel("test accuracy")
# plt.xlabel("model")
# plt.title("CNN models")
make_significance(1, 2, .357, "*")
make_significance(3, 4, .357, "**")
make_significance(5, 6, .357, "*")

plt.text(0.5, 0.305, "conv layer", horizontalalignment = "right")
plt.text(0.5, 0.298, "predictor", horizontalalignment = "right")

right_tick(test_list, 3)
plt.savefig("../results/pics/cnn_models_4_5.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/cnn/2019-05-22-16-41/cnn_model_4_all_runs_p1_ecoli_100000_10000_51_00_cds_False.pyob
# file ../results/cnn/2019-05-22-20-10/cnn_model_4_all_runs_p1_ecoli_100000_10000_51_00_cds_True.pyob
# file ../results/cnn/2019-05-22-18-22/cnn_model_5_all_runs_p1_ecoli_100000_10000_51_00_cds_False.pyob
# file ../results/cnn/2019-05-22-22-06/cnn_model_5_all_runs_p1_ecoli_100000_10000_51_00_cds_True.pyob
# file ../results/cnn/2019-05-23-14-40/cnn_model_5_all_runs_p1_ecoli_100000_10000_99_00_cds_False.pyob
# file ../results/cnn/2019-05-23-13-37/cnn_model_5_all_runs_p1_ecoli_100000_10000_99_00_cds_True.pyob
# 30 30 30 30 30 30

# %%
plt.figure(figsize=(10,4))
test_list = boxplot("../results/cnn/*/*2[0,1]*_all_runs_p1*10000_[0,1,2,5]*.*")
plt.ylim(0.33, 0.39)
plt.xticks(range(1,8), [
        "k3*6\n6+6","k3*6\n12+12","k3*6\n24+24","k3*6\n50+50", "k3*12\n12+12",  "k3*12\n24+24", "k3*12\n50+50",
    ])
plt.ylabel("test accuracy")
# plt.xlabel("model")
# plt.title("two-sided CNN")
make_significance(4, 7, 0.385, "**")

plt.text(0.5, 0.324, "conv layer", horizontalalignment = "right")
plt.text(0.5, 0.316, "predictors", horizontalalignment = "right")
right_tick(test_list, 5)
plt.savefig("../results/pics/cnn_models_two_sided.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/cnn/2019-05-25-01-01/cnn_model_20_all_runs_p1_ecoli_100000_10000_06_00_cds_False.pyob
# file ../results/cnn/2019-05-25-03-56/cnn_model_20_all_runs_p1_ecoli_100000_10000_12_00_cds_False.pyob
# file ../results/cnn/2019-05-25-09-21/cnn_model_20_all_runs_p1_ecoli_100000_10000_24_00_cds_False.pyob
# file ../results/cnn/2019-05-25-11-54/cnn_model_20_all_runs_p1_ecoli_100000_10000_50_00_cds_False.pyob
# file ../results/cnn/2019-05-25-16-09/cnn_model_21_all_runs_p1_ecoli_100000_10000_12_00_cds_False.pyob
# file ../results/cnn/2019-05-27-22-09/cnn_model_21_all_runs_p1_ecoli_100000_10000_24_00.pyob
# file ../results/cnn/2019-05-26-19-14/cnn_model_21_all_runs_p1_ecoli_100000_10000_50_00_cds_False.pyob
# 30 30 30 30 30 30 30

# %%
plt.figure(figsize=(6,4))
test_list = boxplot("../results/cnn/*/*22*_all_runs_p1*100000*.*", 
                    "../results/cnn/*/*20*_all_runs_p1*100000*12*.*")
plt.ylim(0.33, 0.4)
plt.xticks(range(1, 3), ["k3*6+k3*6\n . \n12+12" , "k3*6+k3*6\ndnn*2\n12+12", "k3*6+k3*6\n LSTM(6)\n50"])

right_tick(test_list, 1)
make_significance(1, 2, 0.395, "***")
plt.text(0.5, 0.323, "conv layer", horizontalalignment = "right")
plt.text(0.5, 0.307, "predictors", horizontalalignment = "right")

plt.savefig("../results/pics/cnn_models_modifications.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/cnn/2019-05-25-18-33/cnn_model_22_all_runs_p1_ecoli_100000_10000_12_00_cds_False.pyob
# file ../results/cnn/2019-05-25-03-56/cnn_model_20_all_runs_p1_ecoli_100000_10000_12_00_cds_False.pyob
# 30 30

# %%
plt.figure(figsize=(6, 4))
test_list = boxplot("../results/cnn/*/*21*_all_runs_p1*100000*24*.*")
plt.ylim(0.33, 0.4)
plt.xticks(range(1, 3), ["k3*12+k3*12\n 24+24", "k3*12+k3*12\n 24+24 cds"])
right_tick(test_list, 1)
make_significance(1,2, .395, "***")

plt.text(0.5, 0.323, "conv layer", horizontalalignment = "right")
plt.text(0.5, 0.315, "predictors", horizontalalignment = "right")

plt.savefig("../results/pics/cnn_models_two_sided_coding.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/cnn/2019-05-27-22-09/cnn_model_21_all_runs_p1_ecoli_100000_10000_24_00.pyob
# file ../results/cnn/2019-05-27-19-48/cnn_model_21_all_runs_p1_ecoli_100000_10000_coding_24_00.pyob
# 30 30

# %% [markdown]
# # RNN

# %%
test_list = boxplot("../results/rnn/*/*all_runs*100000**")
plt.ylim(0.31, 0.37)
plt.xticks(range(1,5), ["4 \n 50", "12 \n 50", "12 \n 12", "36 \n 50"] )
plt.ylabel("accuracy")
plt.text(0.5, 0.305, "LSTM hidden states", horizontalalignment = "right")
plt.text(0.5, 0.295, "predictor size", horizontalalignment = "right")
right_tick(test_list, 2, 3)
plt.savefig("../results/pics/rnn_models_all_runs_p1_ecoli_100000_10000_50_0.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# file ../results/rnn/2019-04-30-01-08/rnn_model_1_all_runs_p1_ecoli_100000_10000_50_00.pyob
# file ../results/rnn/2019-04-30-20-28/rnn_model_2_all_runs_p1_ecoli_100000_10000_50_00.pyob
# file ../results/rnn/2019-05-17-23-31/rnn_model_2_all_runs_p2_ecoli_100000_10000_12_00_cds_False.pyob
# file ../results/rnn/2019-05-02-18-07/rnn_model_3_all_runs_p1_ecoli_100000_10000_50_00.pyob
# 8 9 30 30
