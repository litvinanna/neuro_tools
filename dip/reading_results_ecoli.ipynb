# %%
from __future__ import print_function

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from reading import *
from sequence_for_nn import *

path = "../results/ecoli/04-03-17-45_0.0-21.5_Escherichia_coli"

# %%
seq_np = get_seq_np(path)
mask = get_mask(path)
coding = get_coding(path)

# %%
baseline_codons(path)
# Out:
# 100000  200000  300000  400000  500000  600000  700000  800000  900000
# 0.75006779343309693

# %%
baseline(path, n = 1)
# Out:
# 0
# {'baseline_mean': 773679.0,
#  'baseline_part': 0.85509045172813203,
#  'baseline_part_sd': 0.0,
#  'baseline_sd': 0.0}

# %%
# Out:
# 0.74878756664515156

# %%
plot_mistakes(path)
# Out:
# found file ../results/ecoli/04-03-17-45_0.0-21.5_Escherichia_coli/counters.pyob

# %%
counters = get_counters(path)
# Out:
# found file ../results/ecoli/04-03-17-45_0.0-21.5_Escherichia_coli/counters.pyob

# %%
path1 = "../results/ecoli/04-03-19-10_0.0-10.8_Escherichia_coli"

# %%
plot_mistakes(path1)
# Out:
# found file ../results/ecoli/04-03-19-10_0.0-10.8_Escherichia_coli/counters.pyob
